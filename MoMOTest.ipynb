# %% [markdown]
# <a href="https://colab.research.google.com/github/secutron/TesTime/blob/main/MoMOTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Library

# %%
# !git clone --recurse-submodules https://github.com/goodmattg/expertcue
# Out:
# Cloning into 'expertcue'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 330 (delta 15), reused 21 (delta 11), pack-reused 302
# Receiving objects: 100% (330/330), 92.16 KiB | 308.00 KiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
# %cd expertcue
# !git clone --recurse-submodules https://github.com/yzhq97/transmomo.pytorch
# Out:
# /content/expertcue
# Cloning into 'transmomo.pytorch'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 177 (delta 98), reused 162 (delta 85), pack-reused 0
# Receiving objects: 100% (177/177), 56.97 KiB | 318.00 KiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# !pip install -e transmomo.pytorch
_ = !pip install -r transmomo.pytorch/requirements.txt
# Out:
# ERROR: File "setup.py" not found. Directory cannot be installed in editable mode: /content/expertcue/transmomo.pytorch

# %%
# !mkdir -p transmomo.pytorch/data
# !mkdir -p transmomo.pytorch/out
# %cd transmomo.pytorch/data
# Out:
# /content/expertcue/transmomo.pytorch/data

# %%
# !gdown --id 1lMa-4Bspn2_XV4wqo_s9Bfa35-19UAkB
_ = !unzip mixamo_36_800_24.zip
#!rm mixamo_36_800_24.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1lMa-4Bspn2_XV4wqo_s9Bfa35-19UAkB
# To: /content/expertcue/transmomo.pytorch/data/mixamo_36_800_24.zip
# 753MB [00:12, 59.0MB/s]

# %%
# !gdown --id 1366FaH0W2VYVW26ZbQJUp1x5GgMyMXuo
_ = !unzip solo_dance_release.zip
#!rm solo_dance_release.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1366FaH0W2VYVW26ZbQJUp1x5GgMyMXuo
# To: /content/expertcue/transmomo.pytorch/data/solo_dance_release.zip
# 272MB [00:03, 71.2MB/s]

# %%
# %cd ../
# !sh scripts/preprocess.sh
# Out:
# /content/expertcue/transmomo.pytorch
# processing
# 100% 32/32 [00:45<00:00,  1.43s/it]
# 91136 seqs
# processing
# 100% 4/4 [00:00<00:00,  6.81it/s]
# 668 seqs
# finished
# processing
# 100% 8/8 [00:12<00:00,  1.55s/it]
# 33678 seqs

# %%
# !pwd
# !gdown --id 120LeeR1WjdO0Emk_6hVRERu1I6Bimi6Q
# !unzip transmomo_mixamo_36_800_24.zip
#rm transmomo_mixamo_36_800_24.zip
# Out:
# /content/expertcue/transmomo.pytorch
# Downloading...
# From: https://drive.google.com/uc?id=120LeeR1WjdO0Emk_6hVRERu1I6Bimi6Q
# To: /content/expertcue/transmomo.pytorch/transmomo_mixamo_36_800_24.zip
# 18.2MB [00:00, 35.3MB/s]
# Archive:  transmomo_mixamo_36_800_24.zip
#    creating: transmomo_mixamo_36_800_24/
#    creating: transmomo_mixamo_36_800_24/checkpoints/
#   inflating: transmomo_mixamo_36_800_24/checkpoints/autoencoder_00200000.pt
#   inflating: transmomo_mixamo_36_800_24/checkpoints/discriminator_00200000.pt
#   inflating: transmomo_mixamo_36_800_24/checkpoints/optimizer.pt
#   inflating: transmomo_mixamo_36_800_24/config.yaml

# %%
# !pwd
# Out:
# /content/expertcue/transmomo.pytorch

# %%
# %cd ../
# Out:
# /content/expertcue

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/expertcue"
# Out:
# /content/expertcue

# %%
#%tensorflow_version 1.x

# %%
# !git clone https://github.com/carolineec/EverybodyDanceNow.git
# Out:
# Cloning into 'EverybodyDanceNow'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 76 (delta 4), reused 75 (delta 3), pack-reused 0
# Unpacking objects: 100% (76/76), done.

# %%
# !pip install dominate scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 102kB/s
# ...
# ERROR: umap-learn 0.4.6 has requirement scipy>=1.3.1, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %% [markdown]
# ## Preparing Dataset
# Link this url in your Drive
# https://drive.google.com/drive/folders/1rvhzpitXWEN27RD528072mKZ-oyQcyek?usp=sharing

# %%
# %mkdir /content/data
# %cd /content/data
# Out:
# mkdir: cannot create directory ‘/content/data’: File exists
# /content/data

# %%
# !ls /content/drive/My\ Drive/dance\ subjects
# Out:
# filming_instructions.txt  subject1.tar	subject3.tar  subject5.tar
# README.txt		  subject2.tar	subject4.tar  transfer_video_list.txt

# %%
# !tar -xvf /content/drive/My\ Drive/dance\ subjects/subject1.tar

# %% [markdown]
# ## Training

# %%
# %cd /content/EverybodyDanceNow/
# Out:
# /content/EverybodyDanceNow

# %%
# !mkdir checkpoints

# %%
# !python train_fullts.py \
--name subject1_global \
--dataroot /content/data/subject1/train \
--checkpoints_dir ./checkpoints/ \
--loadSize 512 \
--no_instance \
--no_flip \
--tf_log \
--label_nc 6
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints/
# continue_train: False
# dataroot: /content/data/subject1/train
# debug: False
# display_freq: 100
# display_winsize: 512
# faceGtype: unet
# face_discrim: False
# face_generator: False
# feat_num: 3
# fineSize: 512
# gestures: False
# gpu_ids: [0]
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 6
# lambda_A: 10.0
# lambda_F: 1.0
# lambda_feat: 10.0
# loadSize: 512
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_layers_D_face: 3
# n_local_enhancers: 1
# name: subject1_global
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# niter_fix_main: 0
# no_flip: True
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# ...
